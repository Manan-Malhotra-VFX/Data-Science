# %%
from sklearn import datasets

# %%
boston_house = datasets.load_boston()
boston_house
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %% [markdown]
# ## Data Description
# The Boston data frame has 506 rows and 14 columns.
#
# This data frame contains the following columns:
#
# #### Input variables
# * crim - per capita crime rate by town.
#
# * zn - proportion of residential land zoned for lots over 25,000 sq.ft.
#
# * indus - proportion of non-retail business acres per town.
#
# * chas - Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# * nox - nitrogen oxides concentration (parts per 10 million).
#
# * rm - average number of rooms per dwelling.
#
# * age - proportion of owner-occupied units built prior to 1940.
#
# * dis - weighted mean of distances to five Boston employment centres.
#
# * rad - index of accessibility to radial highways.
#
# * tax - full-value property-tax rate per \$10,000.
#
# * ptratio - pupil-teacher ratio by town.
#
# * black 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
#
# * lstat -lower status of the population (percent).
#
# ##### Target Variable
#
# * medv -median value of owner-occupied homes in \$1000s.

# %%
import pandas as pd
X = boston_house.data
y = boston_house.target
house_details = pd.DataFrame(X,columns = boston_house.feature_names)

house_details['TARGET'] = y
house_details.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
#
#    PTRATIO       B  LSTAT  TARGET
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# ...

# %%
house_details.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
house_details.mean()
# Out:
# CRIM         3.613524
# ZN          11.363636
# INDUS       11.136779
# CHAS         0.069170
# NOX          0.554695
# RM           6.284634
# AGE         68.574901
# DIS          3.795043
# RAD          9.549407
# TAX        408.237154
# PTRATIO     18.455534
# B          356.674032
# LSTAT       12.653063
# TARGET      22.532806
# dtype: float64

# %%
house_details.std()
# Out:
# CRIM         8.601545
# ZN          23.322453
# INDUS        6.860353
# CHAS         0.253994
# NOX          0.115878
# RM           0.702617
# AGE         28.148861
# DIS          2.105710
# RAD          8.707259
# TAX        168.537116
# PTRATIO      2.164946
# B           91.294864
# LSTAT        7.141062
# TARGET       9.197104
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(house_details['INDUS'])
# Out:
# (array([ 56.,  95.,  99.,  44.,  20.,   3., 132.,  45.,   0.,  12.]),
#  array([ 0.46 ,  3.188,  5.916,  8.644, 11.372, 14.1  , 16.828, 19.556,
#         22.284, 25.012, 27.74 ]),
#  <BarContainer object of 10 artists>)

# %%
house_details.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# TARGET     0
# dtype: int64

# %%
house_details.shape
# Out:
# (506, 14)

# %%
house_details.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# TARGET     float64
# dtype: object

# %% [markdown]
# ## Model Building

# %%
X = house_details.loc[:,'CRIM':'LSTAT']
y = house_details[['TARGET']]

# %% [markdown]
# ## Model Training - Testing - Evaluation with CV

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

le_model = LinearRegression()
cv_score = cross_val_score(estimator = le_model,X = X, y = y,cv = 5)
print('CV score for 5 folds = {}\nMean Accuracy = {}\nDeviation = {}.'.format(cv_score,cv_score.mean(),cv_score.std()))
# Out:
# CV score for 5 folds = [ 0.63919994  0.71386698  0.58702344  0.07923081 -0.25294154]
# Mean Accuracy = 0.35327592439588273
# Deviation = 0.3765678393326142.

# %% [markdown]
# ## Model Optimization

# %% [markdown]
# ##### 1. Standard Scaler - Mean = 0, STD =1

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
std_scaler = std_scaler.fit_transform(X)

# %%
scaled_house_data = pd.DataFrame(std_scaler,columns = boston_house.feature_names)
scaled_house_data.head(20)
scaled_house_data['TARGET'] = y

# %%
scaled_house_data
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT  TARGET
# ...

# %%
scaled_house_data.mean()
# Out:
# CRIM      -1.123388e-16
# ZN         7.898820e-17
# INDUS      2.106352e-16
# CHAS      -3.510587e-17
# NOX       -1.965929e-16
# RM        -1.088282e-16
# AGE       -1.474446e-16
# DIS       -8.425408e-17
# RAD       -1.123388e-16
# TAX        0.000000e+00
# PTRATIO   -4.212704e-16
# B         -7.442444e-16
# LSTAT     -3.089316e-16
# TARGET     2.253281e+01
# dtype: float64

# %%
scaled_house_data.std()
# Out:
# CRIM       1.000990
# ZN         1.000990
# INDUS      1.000990
# CHAS       1.000990
# NOX        1.000990
# RM         1.000990
# AGE        1.000990
# DIS        1.000990
# RAD        1.000990
# TAX        1.000990
# PTRATIO    1.000990
# B          1.000990
# LSTAT      1.000990
# TARGET     9.197104
# dtype: float64

# %%
X_transformed = scaled_house_data.loc[:,'CRIM':'LSTAT']
y = scaled_house_data[['TARGET']]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

le_model = LinearRegression()
cv_score = cross_val_score(estimator = le_model,X = X_transformed, y = y,cv = 5)
print('CV score for 5 folds = {}\nMean Accuracy = {}\nDeviation = {}.'.format(cv_score,cv_score.mean(),cv_score.std()))
# Out:
# CV score for 5 folds = [ 0.63919994  0.71386698  0.58702344  0.07923081 -0.25294154]
# Mean Accuracy = 0.3532759243958824
# Deviation = 0.3765678393326225.

# %% [markdown]
# #### 2. MinMax Scaler - All the values will be between 0 to 1.

# %%
from sklearn.preprocessing import MinMaxScaler
mm_scaler = MinMaxScaler()
mm_scaler = mm_scaler.fit_transform(X)

# %%
mm_scaled_house_data = pd.DataFrame(mm_scaler,columns = boston_house.feature_names)
mm_scaled_house_data['TARGET'] = y
mm_scaled_house_data.head(20)
# Out:
#         CRIM     ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0   0.000000  0.180  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1   0.000236  0.000  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2   0.000236  0.000  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3   0.000293  0.000  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4   0.000705  0.000  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# 5   0.000264  0.000  0.063050   0.0  0.150206  0.549722  0.574665  0.448545
# 6   0.000921  0.125  0.271628   0.0  0.286008  0.469630  0.656025  0.402923
# 7   0.001554  0.125  0.271628   0.0  0.286008  0.500287  0.959835  0.438387
# 8   0.002303  0.125  0.271628   0.0  0.286008  0.396628  1.000000  0.450354
# 9   0.001840  0.125  0.271628   0.0  0.286008  0.468097  0.854789  0.496731
# 10  0.002457  0.125  0.271628   0.0  0.286008  0.539567  0.941298  0.474416
# ...

# %%
mm_scaled_house_data.mean()
# Out:
# CRIM       0.040544
# ZN         0.113636
# INDUS      0.391378
# CHAS       0.069170
# NOX        0.349167
# RM         0.521869
# AGE        0.676364
# DIS        0.242381
# RAD        0.371713
# TAX        0.422208
# PTRATIO    0.622929
# B          0.898568
# LSTAT      0.301409
# TARGET     0.389618
# dtype: float64

# %%
mm_scaled_house_data.std()
# Out:
# CRIM       0.096679
# ZN         0.233225
# INDUS      0.251479
# CHAS       0.253994
# NOX        0.238431
# RM         0.134627
# AGE        0.289896
# DIS        0.191482
# RAD        0.378576
# TAX        0.321636
# PTRATIO    0.230313
# B          0.230205
# LSTAT      0.197049
# TARGET     0.204380
# dtype: float64

# %%
X_transformed_mm = scaled_house_data.loc[:,'CRIM':'LSTAT']
y_mm = scaled_house_data[['TARGET']]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

le_model = LinearRegression()
cv_score = cross_val_score(estimator = le_model,X = X_transformed_mm, y = y_mm,cv = 5)
print('CV score for 5 folds = {}\nMean Accuracy = {}\nDeviation = {}.'.format(cv_score,cv_score.mean(),cv_score.std()))
# Out:
# CV score for 5 folds = [ 0.63919994  0.71386698  0.58702344  0.07923081 -0.25294154]
# Mean Accuracy = 0.3532759243958824
# Deviation = 0.3765678393326225.

# %%
mm_scaled_house_data.head(5)
# Out:
#        CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0  0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1  0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2  0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3  0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4  0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
#
#         RAD       TAX   PTRATIO         B     LSTAT  TARGET
# 0  0.000000  0.208015  0.287234  1.000000  0.089680    24.0
# 1  0.043478  0.104962  0.553191  1.000000  0.204470    21.6
# 2  0.043478  0.104962  0.553191  0.989737  0.063466    34.7
# 3  0.086957  0.066794  0.648936  0.994276  0.033389    33.4
# 4  0.086957  0.066794  0.648936  1.000000  0.099338    36.2

# %%
from sklearn.preprocessing import MinMaxScaler
rev_mm_scaler = MinMaxScaler()
rev_mm_scaler=rev_mm_scaler.fit(mm_scaled_house_data)

# %%
rrev_mm_scaler= rev_mm_scaler.inverse_transform(mm_scaled_house_data)

# %%
rrev_mm_scaler
# Out:
# array([[0.00000000e+00, 1.80000000e-01, 6.78152493e-02, ...,
#         1.00000000e+00, 8.96799117e-02, 1.08500000e+03],
#        [2.35922539e-04, 0.00000000e+00, 2.42302053e-01, ...,
#         1.00000000e+00, 2.04470199e-01, 9.77000000e+02],
#        [2.35697744e-04, 0.00000000e+00, 2.42302053e-01, ...,
#         9.89737254e-01, 6.34657837e-02, 1.56650000e+03],
#        ...,
#        [6.11892474e-04, 0.00000000e+00, 4.20454545e-01, ...,
#         1.00000000e+00, 1.07891832e-01, 1.08050000e+03],
#        [1.16072990e-03, 0.00000000e+00, 4.20454545e-01, ...,
#         9.91300620e-01, 1.31070640e-01, 9.95000000e+02],
#        [4.61841693e-04, 0.00000000e+00, 4.20454545e-01, ...,
#         1.00000000e+00, 1.69701987e-01, 5.40500000e+02]])

# %%
mm_scaled_house_data.head(5)
# Out:
#        CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0  0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1  0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2  0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3  0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4  0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
#
#         RAD       TAX   PTRATIO         B     LSTAT    TARGET
# 0  0.000000  0.208015  0.287234  1.000000  0.089680  0.422222
# 1  0.043478  0.104962  0.553191  1.000000  0.204470  0.368889
# 2  0.043478  0.104962  0.553191  0.989737  0.063466  0.660000
# 3  0.086957  0.066794  0.648936  0.994276  0.033389  0.631111
# 4  0.086957  0.066794  0.648936  1.000000  0.099338  0.693333

# %% [markdown]
# ##### 1. Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler
rb_scaler = RobustScaler()
rb_scaler = rb_scaler.fit_transform(X)

# %%
rb_scaled_house_data = pd.DataFrame(rb_scaler,columns = boston_house.feature_names)
rb_scaled_house_data['TARGET'] = y
rb_scaled_house_data.head(20)
# Out:
#         CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0  -0.069593  1.44 -0.571650   0.0  0.000000  0.496612 -0.250765  0.285777
# 1  -0.063755  0.00 -0.202943   0.0 -0.394286  0.287940  0.028542  0.569789
# 2  -0.063760  0.00 -0.202943   0.0 -0.394286  1.323171 -0.334353  0.569789
# 3  -0.062347  0.00 -0.581720   0.0 -0.457143  1.069783 -0.646279  0.924391
# 4  -0.052144  0.00 -0.581720   0.0 -0.457143  1.271680 -0.475025  0.924391
# 5  -0.063048  0.00 -0.581720   0.0 -0.457143  0.300136 -0.383282  0.924391
# 6  -0.046792  1.00 -0.140976   0.0 -0.080000 -0.266260 -0.222222  0.761936
# 7  -0.031143  1.00 -0.140976   0.0 -0.080000 -0.049458  0.379205  0.888221
# 8  -0.012592  1.00 -0.140976   0.0 -0.080000 -0.782520  0.458716  0.930835
# 9  -0.024053  1.00 -0.140976   0.0 -0.080000 -0.277100  0.171254  1.095977
# 10 -0.008795  1.00 -0.140976   0.0 -0.080000  0.228320  0.342508  1.016514
# ...

# %%
rb_scaled_house_data.mean()
# Out:
# CRIM        0.933791
# ZN          0.909091
# INDUS       0.112067
# CHAS        0.069170
# NOX         0.095400
# RM          0.103163
# AGE        -0.181959
# DIS         0.190267
# RAD         0.227470
# TAX         0.202163
# PTRATIO    -0.212309
# B          -1.667632
# LSTAT       0.129242
# TARGET     22.532806
# dtype: float64

# %%
rb_scaled_house_data.std()
# Out:
# CRIM       2.392616
# ZN         1.865796
# INDUS      0.531398
# CHAS       0.253994
# NOX        0.662158
# RM         0.952056
# AGE        0.573881
# DIS        0.681846
# RAD        0.435363
# TAX        0.435496
# PTRATIO    0.773195
# B          4.379176
# LSTAT      0.713749
# TARGET     9.197104
# dtype: float64

# %%
X_transformed_rb = rb_scaled_house_data.loc[:,'CRIM':'LSTAT']
y_rb = rb_scaled_house_data[['TARGET']]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

le_model = LinearRegression()
cv_score = cross_val_score(estimator = le_model,X = X_transformed_rb, y = y_rb,cv = 5)
print('CV score for 5 folds = {}\nMean Accuracy = {}\nDeviation = {}.'.format(cv_score,cv_score.mean(),cv_score.std()))
# Out:
# CV score for 5 folds = [ 0.63919994  0.71386698  0.58702344  0.07923081 -0.25294154]
# Mean Accuracy = 0.35327592439588174
# Deviation = 0.3765678393326231.

# %% [markdown]
# # -----------------------------------------------------------------------------------------------

# %% [markdown]
# # ADDITIONAL NOTES
#
# ### MinMaxScaler(feature_range = (0, 1))
# Will transform each value in the column proportionally within the range [0,1]. Use this as the first scaler choice to transform a feature, as it will preserve the shape of the dataset (no distortion).
#
# ### StandardScaler()
# will transform each value in the column to range about the mean 0 and standard deviation 1, ie, each value will be normalised by subtracting the mean and dividing by standard deviation. Use StandardScaler if you know the data distribution is normal.
#
# ### Robust Scaler()
# If there are outliers, use RobustScaler(). Alternatively you could remove the outliers and use either of the above 2 scalers (choice depends on whether data is normally distributed)

# %% [markdown]
# # -------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Transformation for Predictor

# %%
from sklearn.preprocessing import MinMaxScaler
mm_scaler = MinMaxScaler()
mm_scaler_y = mm_scaler.fit_transform(y)

# %%
mm_scaler_y
# Out:
# array([[0.42222222],
#        [0.36888889],
#        [0.66      ],
#        [0.63111111],
#        [0.69333333],
#        [0.52666667],
#        [0.39777778],
#        [0.49111111],
#        [0.25555556],
#        [0.30888889],
#        [0.22222222],
#        [0.30888889],
#        [0.37111111],
#        [0.34222222],
#        [0.29333333],
#        [0.33111111],
#        [0.40222222],
#        [0.27777778],
#        [0.33777778],
#        [0.29333333],
#        [0.19111111],
#        [0.32444444],
#        [0.22666667],
#        [0.21111111],
#        [0.23555556],
#        [0.19777778],
#        [0.25777778],
#        [0.21777778],
#        [0.29777778],
#        [0.35555556],
#        [0.17111111],
#        [0.21111111],
#        [0.18222222],
#        [0.18      ],
#        [0.18888889],
#        [0.30888889],
#        [0.33333333],
#        [0.35555556],
#        [0.43777778],
#        [0.57333333],
#        [0.66444444],
#        [0.48      ],
#        [0.45111111],
# ...

# %%
mm_scaled_house_data
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
# ...

# %%
del mm_scaled_house_data['TARGET']

# %%
mm_scaled_house_data['TARGET'] = mm_scaler_y

# %%
mm_scaled_house_data
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
# ...

# %%
X = mm_scaled_house_data.loc[:,'CRIM':'LSTAT']
y = mm_scaled_house_data['TARGET']

# %%
X
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
#           RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
y
# Out:
# 0      0.422222
# 1      0.368889
# 2      0.660000
# 3      0.631111
# 4      0.693333
#          ...
# 501    0.386667
# 502    0.346667
# 503    0.420000
# 504    0.377778
# 505    0.153333
# Name: TARGET, Length: 506, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

le_model = LinearRegression()
cv_score = cross_val_score(estimator = le_model,X = X, y = y,cv = 5)
print('CV score for 5 folds = {}\nMean Accuracy = {}\nDeviation = {}.'.format(cv_score,cv_score.mean(),cv_score.std()))
# Out:
# CV score for 5 folds = [ 0.63919994  0.71386698  0.58702344  0.07923081 -0.25294154]
# Mean Accuracy = 0.3532759243958822
# Deviation = 0.3765678393326226.

# %% [markdown]
# # TASK -
#
# 1. Apply Robust Scaler and check if there is any impact.
# 2. Why there is no impact even after doing Standardization, MinMax in terms of accuracy?
# 3. Apply train-test split for the same dataset and check the machine predictions with Linear Regression algorithm.

# %% [markdown]
# ##### 1. Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler
rb_scaler = RobustScaler()
rb_scaler = rb_scaler.fit_transform(X)

# %%
rb_scaled_house_data = pd.DataFrame(rb_scaler,columns = boston_house.feature_names)
rb_scaled_house_data['TARGET'] = y
rb_scaled_house_data.head(20)
# Out:
#         CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0  -0.069593  1.44 -0.571650   0.0  0.000000  0.496612 -0.250765  0.285777
# 1  -0.063755  0.00 -0.202943   0.0 -0.394286  0.287940  0.028542  0.569789
# 2  -0.063760  0.00 -0.202943   0.0 -0.394286  1.323171 -0.334353  0.569789
# 3  -0.062347  0.00 -0.581720   0.0 -0.457143  1.069783 -0.646279  0.924391
# 4  -0.052144  0.00 -0.581720   0.0 -0.457143  1.271680 -0.475025  0.924391
# 5  -0.063048  0.00 -0.581720   0.0 -0.457143  0.300136 -0.383282  0.924391
# 6  -0.046792  1.00 -0.140976   0.0 -0.080000 -0.266260 -0.222222  0.761936
# 7  -0.031143  1.00 -0.140976   0.0 -0.080000 -0.049458  0.379205  0.888221
# 8  -0.012592  1.00 -0.140976   0.0 -0.080000 -0.782520  0.458716  0.930835
# 9  -0.024053  1.00 -0.140976   0.0 -0.080000 -0.277100  0.171254  1.095977
# 10 -0.008795  1.00 -0.140976   0.0 -0.080000  0.228320  0.342508  1.016514
# ...

# %%
rb_scaled_house_data.mean()
# Out:
# CRIM       0.933791
# ZN         0.909091
# INDUS      0.112067
# CHAS       0.069170
# NOX        0.095400
# RM         0.103163
# AGE       -0.181959
# DIS        0.190267
# RAD        0.227470
# TAX        0.202163
# PTRATIO   -0.212309
# B         -1.667632
# LSTAT      0.129242
# TARGET     0.389618
# dtype: float64

# %%
rb_scaled_house_data.std()
# Out:
# CRIM       2.392616
# ZN         1.865796
# INDUS      0.531398
# CHAS       0.253994
# NOX        0.662158
# RM         0.952056
# AGE        0.573881
# DIS        0.681846
# RAD        0.435363
# TAX        0.435496
# PTRATIO    0.773195
# B          4.379176
# LSTAT      0.713749
# TARGET     0.204380
# dtype: float64

# %%
X_transformed_rb = rb_scaled_house_data.loc[:,'CRIM':'LSTAT']
y_rb = rb_scaled_house_data[['TARGET']]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

le_model = LinearRegression()
cv_score = cross_val_score(estimator = le_model,X = X_transformed_rb, y = y_rb,cv = 5)
print('CV score for 5 folds = {}\nMean Accuracy = {}\nDeviation = {}.'.format(cv_score,cv_score.mean(),cv_score.std()))
# Out:
# CV score for 5 folds = [ 0.63919994  0.71386698  0.58702344  0.07923081 -0.25294154]
# Mean Accuracy = 0.35327592439588107
# Deviation = 0.3765678393326247.

# %% [markdown]
# ##### 2. There is no impact even after doing Standardization, MinMax in terms of accuracy as its only converting it the values that are easy for a machine to understand, so it only increases the calculation speed

# %% [markdown]
# ##### train-test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 123,test_size = 0.20)

# %%
print(X_train,"\n",X_test,"\n",y_train,"\n",y_test)
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 203  0.000323  0.95  0.081378   0.0  0.063992  0.822380  0.312049  0.362684
# 441  0.109226  0.00  0.646628   0.0  0.730453  0.545124  0.971164  0.085069
# 172  0.001493  0.00  0.131598   0.0  0.257202  0.385323  0.881565  0.133356
# 95   0.001301  0.00  0.089076   0.0  0.123457  0.587086  0.565396  0.215115
# 54   0.000082  0.75  0.129765   0.0  0.051440  0.445871  0.460350  0.562895
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 98   0.000849  0.00  0.089076   0.0  0.123457  0.816057  0.350154  0.215115
# 476  0.054682  0.00  0.646628   0.0  0.471193  0.560069  0.934089  0.106912
# 322  0.003876  0.00  0.253666   0.0  0.222222  0.475187  0.484037  0.326592
# 382  0.103189  0.00  0.646628   0.0  0.648148  0.378425  1.000000  0.040993
# 365  0.051136  0.00  0.646628   0.0  0.685185  0.000000  0.875386  0.043976
#
#           RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
le_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred_train_data = le_model.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error,r2_score
print("MSE : {}.".format(mean_squared_error(y_train,pred_train_data)))
print("R2_score : {}.".format(r2_score(y_train,pred_train_data)))
# Out:
# MSE : 0.010210917505093892.
# R2_score : 0.7559380876016175.

# %%
pred_test_data = le_model.predict(X_test)

# %%
print("MSE : {}.".format(mean_squared_error(y_test,pred_test_data)))
print("R2_score : {}.".format(r2_score(y_test,pred_test_data)))
# Out:
# MSE : 0.013922215189367683.
# R2_score : 0.6592466510354096.

# %% [markdown]
# ## --------------------------------------------------------------------------------------------------------------
